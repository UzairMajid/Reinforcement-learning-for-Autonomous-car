# %%
import gym 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %%
environment_name = "CarRacing-v0"

# %%
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Track generation: 1203..1508 -> 305-tiles track
# Episode:1 Score:-37.500000000000554
# Track generation: 1148..1439 -> 291-tiles track
# Episode:2 Score:-31.03448275862113
# Track generation: 1321..1655 -> 334-tiles track
# Episode:3 Score:-42.94294294294363
# Track generation: 1170..1466 -> 296-tiles track
# Episode:4 Score:-35.59322033898356
# Track generation: 1187..1488 -> 301-tiles track
# Episode:5 Score:-33.33333333333386

# %%
log_path = os.path.join('training_model_RL', 'logs')

# %%
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=40000)
# Out:
# Track generation: 1165..1460 -> 295-tiles track
# 2021-11-16 22:37:04.222255: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/abuuthman/anaconda3/lib/python3.8/site-packages/cv2/../../lib64:
# 2021-11-16 22:37:04.222298: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Logging to training_model_RL/logs/PPO_1
# Track generation: 1152..1444 -> 292-tiles track
# Track generation: 1138..1427 -> 289-tiles track
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -57.3    |
# | time/              |          |
# |    fps             | 74       |
# |    iterations      | 1        |
# |    time_elapsed    | 27       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Track generation: 1008..1267 -> 259-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1227..1538 -> 311-tiles track
# Track generation: 1056..1324 -> 268-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -55.3        |
# | time/                   |              |
# |    fps                  | 50           |
# |    iterations           | 2            |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0052292533 |
# |    clip_fraction        | 0.0438       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.00566      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.217        |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00162     |
# |    std                  | 0.993        |
# |    value_loss           | 0.627        |
# ------------------------------------------
# Track generation: 1124..1409 -> 285-tiles track
# Track generation: 1048..1316 -> 268-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1208..1514 -> 306-tiles track
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -50.8        |
# | time/                   |              |
# |    fps                  | 47           |
# |    iterations           | 3            |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0101738125 |
# |    clip_fraction        | 0.111        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.23        |
# |    explained_variance   | 0.0485       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.199        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00946     |
# |    std                  | 0.985        |
# |    value_loss           | 0.575        |
# ------------------------------------------
# Track generation: 1262..1582 -> 320-tiles track
# Track generation: 959..1208 -> 249-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -51.2       |
# | time/                   |             |
# |    fps                  | 44          |
# |    iterations           | 4           |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011434595 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.0961      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0615      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0135     |
# |    std                  | 0.966       |
# |    value_loss           | 0.539       |
# -----------------------------------------
# Track generation: 1014..1279 -> 265-tiles track
# Track generation: 1344..1684 -> 340-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -48.8      |
# | time/                   |            |
# |    fps                  | 43         |
# |    iterations           | 5          |
# |    time_elapsed         | 233        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01127385 |
# |    clip_fraction        | 0.125      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.14      |
# |    explained_variance   | -0.183     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.147      |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0144    |
# |    std                  | 0.957      |
# |    value_loss           | 0.448      |
# ----------------------------------------
# Track generation: 1119..1403 -> 284-tiles track
# Track generation: 1147..1438 -> 291-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.8       |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 6           |
# |    time_elapsed         | 279         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.014419381 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | -0.0358     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.252       |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0181     |
# |    std                  | 0.958       |
# |    value_loss           | 0.769       |
# -----------------------------------------
# Track generation: 1283..1608 -> 325-tiles track
# Track generation: 1145..1436 -> 291-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49.3       |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 7           |
# |    time_elapsed         | 326         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.015288308 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | 0.00924     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0124      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0222     |
# |    std                  | 0.953       |
# |    value_loss           | 0.385       |
# -----------------------------------------
# Track generation: 1073..1353 -> 280-tiles track
# Track generation: 1112..1394 -> 282-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49.3       |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 8           |
# |    time_elapsed         | 374         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.017482113 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.234       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0232      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0239     |
# |    std                  | 0.948       |
# |    value_loss           | 0.272       |
# -----------------------------------------
# Track generation: 1116..1399 -> 283-tiles track
# Track generation: 1109..1399 -> 290-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -50.4       |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 9           |
# |    time_elapsed         | 420         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.017557818 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | -0.0698     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0845      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0235     |
# |    std                  | 0.943       |
# |    value_loss           | 0.382       |
# -----------------------------------------
# Track generation: 1183..1483 -> 300-tiles track
# Track generation: 1154..1446 -> 292-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52.5       |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 10          |
# |    time_elapsed         | 469         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.017944753 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.06       |
# |    explained_variance   | 0.451       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0407      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0253     |
# |    std                  | 0.929       |
# |    value_loss           | 0.258       |
# -----------------------------------------
# Track generation: 1050..1316 -> 266-tiles track
# Track generation: 1192..1504 -> 312-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -53.7       |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 11          |
# |    time_elapsed         | 521         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.017204836 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4          |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00408     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0194     |
# |    std                  | 0.909       |
# |    value_loss           | 0.182       |
# -----------------------------------------
# Track generation: 1198..1502 -> 304-tiles track
# Track generation: 1349..1683 -> 334-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -55.1       |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 12          |
# |    time_elapsed         | 570         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.022336582 |
# |    clip_fraction        | 0.224       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.97       |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0457     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0253     |
# |    std                  | 0.905       |
# |    value_loss           | 0.205       |
# -----------------------------------------
# Track generation: 1155..1448 -> 293-tiles track
# Track generation: 1331..1668 -> 337-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -55.1       |
# | time/                   |             |
# |    fps                  | 42          |
# |    iterations           | 13          |
# |    time_elapsed         | 621         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.025774784 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.93       |
# |    explained_variance   | 0.856       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0248     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.031      |
# |    std                  | 0.889       |
# |    value_loss           | 0.189       |
# -----------------------------------------
# Track generation: 1095..1373 -> 278-tiles track
# Track generation: 1222..1532 -> 310-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -55.1      |
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 14         |
# |    time_elapsed         | 668        |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.02818405 |
# |    clip_fraction        | 0.266      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.9       |
# |    explained_variance   | 0.873      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0184    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0278    |
# |    std                  | 0.885      |
# |    value_loss           | 0.216      |
# ----------------------------------------
# Track generation: 1100..1379 -> 279-tiles track
# Track generation: 1096..1374 -> 278-tiles track
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1e+03     |
# |    ep_rew_mean          | -52.1     |
# | time/                   |           |
# |    fps                  | 42        |
# |    iterations           | 15        |
# |    time_elapsed         | 717       |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.0330477 |
# |    clip_fraction        | 0.292     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.87     |
# |    explained_variance   | 0.85      |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0536    |
# |    n_updates            | 140       |
# |    policy_gradient_loss | -0.0299   |
# |    std                  | 0.876     |
# |    value_loss           | 0.303     |
# ---------------------------------------
# Track generation: 997..1250 -> 253-tiles track
# Track generation: 1044..1309 -> 265-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -48        |
# | time/                   |            |
# |    fps                  | 42         |
# |    iterations           | 16         |
# |    time_elapsed         | 765        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.03021823 |
# |    clip_fraction        | 0.281      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.85      |
# |    explained_variance   | 0.829      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0378     |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0307    |
# |    std                  | 0.873      |
# |    value_loss           | 0.49       |
# ----------------------------------------
# Track generation: 1019..1282 -> 263-tiles track
# Track generation: 1068..1346 -> 278-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.5       |
# | time/                   |             |
# |    fps                  | 42          |
# |    iterations           | 17          |
# |    time_elapsed         | 813         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.037242524 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.82       |
# |    explained_variance   | 0.851       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.105       |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0326     |
# |    std                  | 0.859       |
# |    value_loss           | 0.527       |
# -----------------------------------------
# Track generation: 1177..1481 -> 304-tiles track
# Track generation: 1251..1568 -> 317-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -46.8       |
# | time/                   |             |
# |    fps                  | 42          |
# |    iterations           | 18          |
# |    time_elapsed         | 866         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.031744625 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.79       |
# |    explained_variance   | 0.914       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0347      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0206     |
# |    std                  | 0.853       |
# |    value_loss           | 0.378       |
# -----------------------------------------
# Track generation: 1197..1509 -> 312-tiles track
# Track generation: 1112..1396 -> 284-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1191..1493 -> 302-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -47.4       |
# | time/                   |             |
# |    fps                  | 42          |
# |    iterations           | 19          |
# |    time_elapsed         | 914         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.032166876 |
# |    clip_fraction        | 0.305       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.77       |
# |    explained_variance   | 0.945       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0357     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.031      |
# |    std                  | 0.849       |
# |    value_loss           | 0.182       |
# -----------------------------------------
# Track generation: 1230..1542 -> 312-tiles track
# Track generation: 1312..1644 -> 332-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -44.6       |
# | time/                   |             |
# |    fps                  | 42          |
# |    iterations           | 20          |
# |    time_elapsed         | 962         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.026488973 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.74       |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0129     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0311     |
# |    std                  | 0.833       |
# |    value_loss           | 0.328       |
# -----------------------------------------

# %%
ppo_path = os.path.join('Training', 'Saved Models', 'PPO_Driving_model')

# %%
model.save(ppo_path)
# Out:
# /home/abuuthman/anaconda3/lib/python3.8/site-packages/stable_baselines3/common/save_util.py:276: UserWarning: Path 'Training/Saved Models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# /home/abuuthman/anaconda3/lib/python3.8/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Track generation: 1147..1438 -> 291-tiles track
# Track generation: 1061..1330 -> 269-tiles track
# Track generation: 1224..1534 -> 310-tiles track
# Track generation: 1101..1380 -> 279-tiles track
# Track generation: 1154..1455 -> 301-tiles track
# Track generation: 1082..1357 -> 275-tiles track
# Track generation: 1079..1353 -> 274-tiles track
# Track generation: 1268..1589 -> 321-tiles track
# Track generation: 1114..1404 -> 290-tiles track
# Track generation: 1052..1319 -> 267-tiles track
# Track generation: 1047..1317 -> 270-tiles track
# (202.12074406147002, 118.7149286473701)

# %%
env.close()

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
